# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
df=pd.read_csv('C:\\Users\\aftha\\OneDrive\\Desktop\\dog_breeds.csv')
df1=df.copy()

# %%
df1
# Out:
#                               Name  min_life_expectancy  max_life_expectancy  \
# 0                 Golden Retriever                   10                   12
# 1                        Dachshund                   12                   16
# 2               Labrador Retriever                   10                   12
# 3                       Great Dane                    7                   10
# 4                            Boxer                   10                   12
# ..                             ...                  ...                  ...
# 92  American Staffordshire Terrier                   12                   16
# 93             Australian Shepherd                   12                   15
# 94            Pembroke Welsh Corgi                   12                   13
# 95               Yorkshire Terrier                   11                   15
# 96                  French Bulldog                   10                   12
#
# ...

# %%
df1.set_index('Name')
# Out:
#                                 min_life_expectancy  max_life_expectancy  \
# Name
# Golden Retriever                                 10                   12
# Dachshund                                        12                   16
# Labrador Retriever                               10                   12
# Great Dane                                        7                   10
# Boxer                                            10                   12
# ...                                             ...                  ...
# American Staffordshire Terrier                   12                   16
# Australian Shepherd                              12                   15
# Pembroke Welsh Corgi                             12                   13
# Yorkshire Terrier                                11                   15
# French Bulldog                                   10                   12
#
#                                 max_height_male  max_height_female  \
# Name
# ...

# %%
df2
# Out:
#                   Name  min_life_expectancy  max_life_expectancy  \
# 0     Golden Retriever                   10                   12
# 1            Dachshund                   12                   16
# 2   Labrador Retriever                   10                   12
# 3           Great Dane                    7                   10
# 4                Boxer                   10                   12
# 5            Dalmatian                   11                   13
# 6   Poodle (Miniature)                   10                   18
# 7          Bullmastiff                    7                    9
# 8               Beagle                   10                   15
# 9        Border Collie                   12                   15
# 10      Siberian Husky                   12                   14
#
#     max_height_male  max_height_female  max_weight_male  max_weight_female  \
# 0              24.0               24.0             75.0               65.0
# ...

# %%
df2=df1.iloc[0:11,0:11]

# %%
a=float(df2[['min_life_expectancy']].mean())

# %%
print(f'the average min life expectancy of a dog = {a} years ')
# Out:
# the average min life expectancy of a dog = 10.090909090909092 years

# %%
b=float(df2['max_life_expectancy'].mean())

# %%
print(f'the average max life expectancy of a dog = {b} years ')
# Out:
# the average max life expectancy of a dog = 13.272727272727273 years

# %%
df2['max_height_male'].max()
# Out:
# 32.0

# %%
df2['max_height_female'].max()
# Out:
# 32.0

# %%
df2['min_height_male'].min()
# Out:
# 8.0

# %%
df2['min_height_female'].min()
# Out:
# 8.0
