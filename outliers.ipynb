# %%
import pandas as pd

# %%
import os

# %%
df=pd.read_csv("C:\\Users\\aftha\\OneDrive\\Desktop\\Flipkart_Mobiles.csv")

# %%
df1=df.copy()

# %%
df1
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
q1=df1["Selling Price"].quantile(0.25)
q2=df1["Selling Price"].quantile(0.50)
q3=df1["Selling Price"].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR

# %%
low_limit
# Out:
# -1018.4091218310914

# %%
upper_limit
# Out:
# 28337.34853638515

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df1["Selling Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x139aa012460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x139aa012a00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x139aa0122b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x139aa012fa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x139aa01f2b0>],
#  'means': []}

# %%
a=(df1["Selling Price"]>upper_limit)|(df1["Selling Price"]<low_limit)

# %%
b=df1[a].index.values
b
#b.shape
# Out:
# array([  25,   26,   75,   76,   87,   90,   91,  107,  177,  186,  190,
#         192,  204,  249,  250,  254,  304,  315,  318,  327,  328,  329,
#         335,  336,  344,  349,  362,  369,  381,  474,  568,  569,  570,
#         619,  626,  627,  628,  629,  631,  632,  633,  715,  766, 1040,
#        1052, 1111, 1120, 1121, 1122, 1263, 1268, 1277, 1280, 1293, 1359,
#        1364, 1373, 1387, 1417, 1418, 1422, 1432, 1440, 1442, 1446, 1451,
#        1483, 1524, 1579, 1588, 1627, 1662, 1674, 1680, 1740, 1754, 1759,
#        1761, 1765, 1831, 1871, 1881, 1896, 1937, 2024, 2041, 2059, 2070,
#        2074, 2082, 2100, 2118, 2120, 2151, 2174, 2176, 2243, 2311, 2320,
#        2433, 2434, 2435, 2436, 2437, 2438, 2439, 2440, 2441, 2442, 2488,
#        2489, 2490, 2574, 2575, 2576, 2705, 2706, 2707, 2708, 2711, 2712,
#        2715, 2736, 2739, 2750, 2751, 2754, 2756, 2757, 2760, 2774, 2775,
#        2776, 2777, 2781, 2830, 2834, 2836, 2854, 3012, 3024, 3025, 3070,
# ...

# %%
df1.drop(b)
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
df1
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           3114 non-null   object
#  1   Model           3114 non-null   object
#  2   Color           3114 non-null   object
#  3   Memory          3071 non-null   object
#  4   Storage         3075 non-null   object
#  5   Rating          2970 non-null   float64
#  6   Selling Price   3114 non-null   int64
#  7   Original Price  3114 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 194.8+ KB

# %%
def IQR_values(df1,Column_name):
    q1=df1[Column_name].quantile(0.25)
    q2=df1[Column_name].quantile(0.50)
    q3=df1[Column_name].quantile(0.75)
    IQR=q3-q1
    low_limit=q1-1.5*IQR
    upper_limit=q3+1.5*IQR
    return low_limit,upper_limit

# %%
l=['Selling Price','Original Price']
j={}
for i in l:
   low_limit,upper_limit= IQR_values(df1,i)
   j[i]=[low_limit,upper_limit]

# %%
j
# Out:
# {'Selling Price': [-1018.4091218310914, 28337.34853638515],
#  'Original Price': [-17424.584537572257, 55788.30756262042]}

# %%
x=[]
for i in l:
    a=df1[(df1[i]>j[i][1])|(df1[i]<j[i][0])].index.values
    x.append(a)

# %%
c.shape
# Out:
# (345,)

# %%
x
# Out:
# [array([  25,   26,   75,   76,   87,   90,   91,  107,  177,  186,  190,
#          192,  204,  249,  250,  254,  304,  315,  318,  327,  328,  329,
#          335,  336,  344,  349,  362,  369,  381,  474,  568,  569,  570,
#          619,  626,  627,  628,  629,  631,  632,  633,  715,  766, 1040,
#         1052, 1111, 1120, 1121, 1122, 1263, 1268, 1277, 1280, 1293, 1359,
#         1364, 1373, 1387, 1417, 1418, 1422, 1432, 1440, 1442, 1446, 1451,
#         1483, 1524, 1579, 1588, 1627, 1662, 1674, 1680, 1740, 1754, 1759,
#         1761, 1765, 1831, 1871, 1881, 1896, 1937, 2024, 2041, 2059, 2070,
#         2074, 2082, 2100, 2118, 2120, 2151, 2174, 2176, 2243, 2311, 2320,
#         2433, 2434, 2435, 2436, 2437, 2438, 2439, 2440, 2441, 2442, 2488,
#         2489, 2490, 2574, 2575, 2576, 2705, 2706, 2707, 2708, 2711, 2712,
#         2715, 2736, 2739, 2750, 2751, 2754, 2756, 2757, 2760, 2774, 2775,
#         2776, 2777, 2781, 2830, 2834, 2836, 2854, 3012, 3024, 3025, 3070,
# ...

# %%
df1
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
for i in range(len(x)):
    df1.loc[x[i],l[i]]=df1[l[i]].mean()

# %%
df1.loc[x[0],l[0]]
# Out:
# 86       60990
# 215      60990
# 256      69999
# 258      71000
# 259      71000
#          ...
# 3055    159900
# 3056    159900
# 3057    179900
# 3058    179900
# 3100     59990
# Name: Selling Price, Length: 358, dtype: int64

# %%
a=df1.loc[x[0],l[0]]=df1[l[0]].mean()
a
# Out:
# 17435.63781263044

# %%
df1.iloc[255:,:]
# Out:
#              Brand   Model          Color Memory Storage  Rating  \
# 255   Google Pixel  3a XL   Clearly White   4 GB   64 GB     4.5
# 256   Google Pixel       3     Just Black   4 GB   64 GB     4.5
# 257   Google Pixel  3a XL      Just Black   4 GB   64 GB     4.5
# 258   Google Pixel       3  Clearly White   4 GB   64 GB     4.5
# 259   Google Pixel       3       Not Pink   4 GB   64 GB     4.5
# ...            ...     ...            ...    ...     ...     ...
# 3109       SAMSUNG  M52 5G  Blazing Black   6 GB  128 GB     4.3
# 3110       SAMSUNG  M52 5G       Icy Blue   6 GB  128 GB     4.3
# 3111       SAMSUNG  M52 5G       Icy Blue   8 GB  128 GB     4.3
# 3112       SAMSUNG  M52 5G    Slate Black   8 GB  128 GB     4.2
# 3113       SAMSUNG  M52 5G       Sky Blue   8 GB  128 GB     4.2
#
#       Selling Price  Original Price
# 255    17316.672868    44999.000000
# 256    17328.939415    28333.473025
# 257    17316.672868    44999.000000
# 258    17328.939415    28333.473025
# ...

# %%
df.iloc[255:,:]
# Out:
#              Brand   Model          Color Memory Storage  Rating  \
# 255   Google Pixel  3a XL   Clearly White   4 GB   64 GB     4.5
# 256   Google Pixel       3     Just Black   4 GB   64 GB     4.5
# 257   Google Pixel  3a XL      Just Black   4 GB   64 GB     4.5
# 258   Google Pixel       3  Clearly White   4 GB   64 GB     4.5
# 259   Google Pixel       3       Not Pink   4 GB   64 GB     4.5
# ...            ...     ...            ...    ...     ...     ...
# 3109       SAMSUNG  M52 5G  Blazing Black   6 GB  128 GB     4.3
# 3110       SAMSUNG  M52 5G       Icy Blue   6 GB  128 GB     4.3
# 3111       SAMSUNG  M52 5G       Icy Blue   8 GB  128 GB     4.3
# 3112       SAMSUNG  M52 5G    Slate Black   8 GB  128 GB     4.2
# 3113       SAMSUNG  M52 5G       Sky Blue   8 GB  128 GB     4.2
#
#       Selling Price  Original Price
# 255           44999           44999
# 256           69999           69999
# 257           44999           44999
# 258           71000           71000
# ...

# %%
plt.boxplot(df1["Original Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x139aa0d9340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x139aa0d98e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x139aa0d9190>],
#  'medians': [<matplotlib.lines.Line2D at 0x139aa0d9e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x139aa0e7190>],
#  'means': []}
