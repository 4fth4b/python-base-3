# %%
import pandas as pd

# %%
import os

# %%
df=pd.read_excel("C:\\Users\\aftha\\Downloads\\visualisation\\Dataset_w6.xlsx")

# %%
df1=df.copy()

# %%
df1
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %%
df1[df1["Region"]=="EasternAfrica"].index.shape
# Out:
# (17,)

# %%
import matplotlib.pyplot as plt

# %%
df1["Population in thousands (2017)"].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df1[df1.iloc[:5,5:6],df1.iloc[:5,4:5]].plot(kind='bar',color='maroon')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(   Agricultural production index
# 0                           125.0
# 1                           134.0
# 2                           160.0
# 3                           175.0
# 4                            88.0,    GDP per capita (current US$)
# 0                         623.2
# 1                        3984.2
# 2                        4154.1
# 3                        4714.1
# ...

# %%
plt.plot(df1.iloc[:5,4:5].dtype=='int64',df1.iloc[:5,5:6].dtype=='int64',color='maroon')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 plt.plot(df1.iloc[:5,4:5].dtype=='int64',df1.iloc[:5,5:6].dtype=='int64',color='maroon')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df1.iloc[0:,4:5].plot(kind='bar',color="maroon")
# Out:
# <AxesSubplot:xlabel='GDP per capita (current US$)'>

# %%
df1.iloc[:5,5:6]
# Out:
#    Agricultural production index
# 0                           125.0
# 1                           134.0
# 2                           160.0
# 3                           175.0
# 4                            88.0

# %%
df2=df1.set_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 df2=df1.set_index("GDP per capita (current US$)")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# ...

# %%
df1
# Out:
#                                                          country  \
# GDP per capita (current US$)
# 623.2                                                Afghanistan
# 3984.2                                                   Albania
# 4154.1                                                   Algeria
# 4714.1                                                    Angola
# 14764.5                                      Antigua and Barbuda
# ...                                                          ...
# 11068.9                       Venezuela (Bolivarian Republic of)
# 2067.9                                                  Viet Nam
# 1106.4                                                     Yemen
# 1311.1                                                    Zambia
# 890.4                                                   Zimbabwe
#
#                                          Region  Surface area (km2)  \
# GDP per capita (current US$)
# ...

# %%
df4=df.copy()
df4.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'GDP per capita (current US$)',
#        'Agricultural production index ',
#        'International trade: Imports (million US$)'],
#       dtype='object')

# %%
df4.groupby('GDP per capita (current US$)')['Agricultural production index '].plot(kind='bar')
plt.show()

# %%
df5=df4.sort_values(by='International trade: Imports (million US$)',ascending=False)

# %%
df5
# Out:
#                               country           Region  Surface area (km2)  \
# 187          United States of America  NorthernAmerica           9833517.0
# 39                              China      EasternAsia           9600000.0
# 69                            Germany    WesternEurope            357376.0
# 185                    United Kingdom   NorthernEurope            242495.0
# 90                              Japan      EasternAsia            377930.0
# ..                                ...              ...                 ...
# 43                       Cook Islands        Polynesia               236.0
# 111                  Marshall Islands       Micronesia               181.0
# 115  Micronesia (Federated States of)       Micronesia               702.0
# 118                        Montserrat        Caribbean               103.0
# 181                            Tuvalu        Polynesia                26.0
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# ...

# %%
df5=df5.set_index('Region')

# %%
df5
# Out:
#                                           country  Surface area (km2)  \
# Region
# NorthernAmerica          United States of America           9833517.0
# EasternAsia                                 China           9600000.0
# WesternEurope                             Germany            357376.0
# NorthernEurope                     United Kingdom            242495.0
# EasternAsia                                 Japan            377930.0
# ...                                           ...                 ...
# Polynesia                            Cook Islands               236.0
# Micronesia                       Marshall Islands               181.0
# Micronesia       Micronesia (Federated States of)               702.0
# Caribbean                              Montserrat               103.0
# Polynesia                                  Tuvalu                26.0
#
#                  Population in thousands (2017)  GDP per capita (current US$)  \
# Region
# ...

# %%
df5.plot('International trade: Imports (million US$)',kind='bar')
# Out:
# <AxesSubplot:xlabel='International trade: Imports (million US$)'>

# %%
plt.barh(df4['Region'],df4['International trade: Imports (million US$)'], color='purple')
plt.xlim(10000,2500000)
# Out:
# (10000.0, 2500000.0)

# %%
plt.scatter(df4['Population in thousands (2017)'],df4['International trade: Imports (million US$)'])

# %%
plt.scatter(df4['GDP per capita (current US$)'],df4['Region'])
