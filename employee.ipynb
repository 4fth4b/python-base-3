# %%
import pandas as pd

# %%
import os

# %%
df=pd.read_csv("C:\\Users\\aftha\\Downloads\\New folder\\employee.csv")

# %%
df1=df.copy()

# %%
df1
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# 6   James Authur  54.0      NaN      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
df1=df1.set_index('name')

# %%
df1.describe(include='all')
# Out:
#                name        age        income gender  department grade  \
# count             9   7.000000      7.000000      7           9     9
# unique            9        NaN           NaN      2           3     4
# top     Allen Smith        NaN           NaN      F  Operations    G3
# freq              1        NaN           NaN      5           3     5
# mean            NaN  40.428571  52857.142857    NaN         NaN   NaN
# std             NaN  12.204605  26028.372797    NaN         NaN   NaN
# min             NaN  23.000000  16000.000000    NaN         NaN   NaN
# 25%             NaN  31.000000  38500.000000    NaN         NaN   NaN
# 50%             NaN  45.000000  52000.000000    NaN         NaN   NaN
# 75%             NaN  49.500000  63500.000000    NaN         NaN   NaN
# max             NaN  54.000000  98000.000000    NaN         NaN   NaN
#
#         performance_score
# count            9.000000
# unique                NaN
# top                   NaN
# ...

# %%
df1['age'].unique()
# Out:
# array([45., nan, 32., 30., 54., 23.])

# %%
df1.loc[['Josh Wills','Jack Morgan']]
# Out:
#               age   income gender department grade  performance_score
# name
# Josh Wills   54.0  52000.0      F    Finance    G3                901
# Jack Morgan  32.0  35000.0      M    Finance    G2                674

# %%
df1[df1['performance_score']>700]
# Out:
#                 age   income gender  department grade  performance_score
# name
# Allen Smith    45.0      NaN    NaN  Operations    G3                723
# Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# Josh Wills     54.0  52000.0      F     Finance    G3                901
# Leo Duck       23.0  98000.0      M       Sales    G4                709

# %%
df1=df1.set_index('department')

# %%
df1.loc[['Sales','Finance']]
# Out:
#              age   income gender grade  performance_score
# department
# Sales       45.0  65000.0      F    G3                556
# Sales        NaN  62000.0    NaN    G3                649
# Sales       23.0  98000.0      M    G4                709
# Finance      NaN  16000.0      F    G0                520
# Finance     32.0  35000.0      M    G2                674
# Finance     54.0  52000.0      F    G3                901

# %%
df1=df1[df1['performance_score']>500]

# %%
df1=df1[df1['performance_score']<700]

# %%
df1
# Out:
#              age   income gender grade  performance_score
# department
# Finance      NaN  16000.0      F    G0                520
# Finance     32.0  35000.0      M    G2                674
# Sales       45.0  65000.0      F    G3                556
# Sales        NaN  62000.0    NaN    G3                649

# %%
df2=df.copy()

# %%
df2
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# 6   James Authur  54.0      NaN      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
df2.interpolate(method='pad')
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar  45.0  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma  30.0  62000.0      F       Sales    G3                649
# 6   James Authur  54.0  62000.0      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709
