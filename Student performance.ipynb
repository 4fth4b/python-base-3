# %%
import pandas as pd

# %%
import os

# %%
df=pd.read_csv("C:\\Users\\aftha\\Downloads\\Students performance\\StudentsPerformance.csv")

# %%
df1=df.copy()

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
count=0
for i in df1['gender']:
    if i=='female':
        count+=1

# %%
count
# Out:
# 518

# %%
df1['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
male=df['gender']=='male'

# %%
m=df[male]

# %%
x=m['math score'].mean()

# %%
x
# Out:
# 68.82157676348548

# %%
y=m['reading score'].mean()

# %%
y
# Out:
# 65.54564315352697

# %%
z=m['writing score'].mean()

# %%
z
# Out:
# 63.446058091286304

# %%
mmean=(x+y+z)/3

# %%
mmean
# Out:
# 65.93775933609959

# %%
female=df['gender']=='female'

# %%
f=df[female]

# %%
x=f['math score'].mean()

# %%
x
# Out:
# 63.37644787644788

# %%
y=f['reading score'].mean()

# %%
y
# Out:
# 72.59073359073359

# %%
z=f['writing score'].mean()

# %%
z
# Out:
# 72.46718146718146

# %%
fmean=(x+y+z)/3

# %%
fmean
# Out:
# 69.47812097812097

# %%
df1['mean']=(df1['math score']+df1['reading score']+df1['writing score'])/3

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df2=df1[df1['test preparation course']=='completed']

# %%
df2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 5    female        group B                 high school  free/reduced
# 10   female        group C            some high school  free/reduced
# 12   female        group B            some high school      standard
# 16   female        group A                 high school  free/reduced
# 21   female        group D            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df3=df1[df1['test preparation course']=='none']

# %%
a=df3['mean'].index.sort_values(ascending=False)
a
# Out:
# Int64Index([991, 990, 987, 986, 984, 981, 979, 978, 974, 971,
#             ...
#              11,   9,   8,   7,   6,   4,   3,   2,   1,   0],
#            dtype='int64', length=642)

# %%
df3.sort_values(by='mean',ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# 512  female        group D                some college      standard
# 501  female        group D             master's degree      standard
# 510  female        group B           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 519    male        group A                some college  free/reduced
# 520    male        group B                 high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
top_25=df.sort_values('math score',ascending=False)

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df1['Total']=df1['math score'].std()

# %%
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df1.groupby(['gender'])['math score','reading score','writing score'].std()
# Out:
# C:\Users\aftha\AppData\Local\Temp\ipykernel_20468\3241695262.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['gender'])['math score','reading score','writing score'].std()
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
df1.groupby(['gender'])['math score','reading score','writing score'].agg([min,max])
# Out:
# C:\Users\aftha\AppData\Local\Temp\ipykernel_20468\4057189790.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['gender'])['math score','reading score','writing score'].agg([min,max])
#        math score      reading score      writing score
#               min  max           min  max           min  max
# gender
# female          0  100            17  100            10  100
# male           27  100            23  100            15  100

# %%
df1.groupby(['test preparation course'])['math score','reading score','writing score'].std()
# Out:
# C:\Users\aftha\AppData\Local\Temp\ipykernel_20468\195935952.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['test preparation course'])['math score','reading score','writing score'].std()
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %%
df1.groupby(['test preparation course'])['math score','reading score','writing score'].agg([min,max])
# Out:
# C:\Users\aftha\AppData\Local\Temp\ipykernel_20468\3493350256.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['test preparation course'])['math score','reading score','writing score'].agg([min,max])
#                         math score      reading score      writing score
#                                min  max           min  max           min  max
# test preparation course
# completed                       23  100            37  100            36  100
# none                             0  100            17  100            10  100

# %%
df1.groupby(['test preparation course'])['math score','reading score','writing score'].mean()
# Out:
# C:\Users\aftha\AppData\Local\Temp\ipykernel_20468\2826052857.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['test preparation course'])['math score','reading score','writing score'].mean()
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
df1.groupby(['gender'])['math score','reading score','writing score'].mean()
# Out:
# C:\Users\aftha\AppData\Local\Temp\ipykernel_20468\372867101.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['gender'])['math score','reading score','writing score'].mean()
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
df2['mean'].quantile(.25)
# Out:
# 65.41666666666666

# %%
df2.iloc[0:,0:91]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 df2.iloc[0:,0:91]
#
# AttributeError: 'float' object has no attribute 'iloc'

# %%
top_25
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 494  female        group D           bachelor's degree      standard
# 495  female        group B             master's degree      standard
# 496  female        group B          associate's degree      standard
# 497  female        group C          associate's degree      standard
# 498  female        group C          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
top_25.quantile(0.75,axis=0)
# Out:
# math score       77.00
# reading score    79.25
# writing score    79.00
# Name: 0.75, dtype: float64

# %%
top_25=df[df['math score']>77]

# %%
top_25
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 430  female        group A                some college      standard
# 431  female        group B           bachelor's degree  free/reduced
# 432  female        group D           bachelor's degree      standard
# 433  female        group D                 high school      standard
# 434  female        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
top_25=df.sort_values('math score',ascending=False)

# %%
import numpy as np

# %%
df['bonus']=np.where(df['math score']>77,(df['reading score']+df['math score']+df['writing score']+10),(df['reading score']+df['math score']+df['writing score']))

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  bonus
# ...
