# %%
import pandas as pd

# %%
import os

# %%
df=pd.read_csv("C:\\Users\\aftha\\OneDrive\\Desktop\\Flipkart_Mobiles.csv")

# %%
df1=df.copy()

# %%
df1
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# 1              15990
# 2              17990
# 3              17990
# 4              15990
# ...              ...
# 3109           25990
# 3110           28449
# 3111           31489
# 3112           22989
# 3113           22595
#
# [3114 rows x 8 columns]

# %%
q1=df1["Selling Price"].quantile(0.25)
q2=df1["Selling Price"].quantile(0.50)
q3=df1["Selling Price"].quantile(0.75)
IQR=q3-q1
low_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
# Out:
# 28999.0

# %%
low_limit
# Out:
# -18523.5

# %%
upper_limit
# Out:
# 57512.5

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df1["Selling Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c20de5e790>,
#   <matplotlib.lines.Line2D at 0x1c20de5ea60>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c20de5edf0>,
#   <matplotlib.lines.Line2D at 0x1c20de7b040>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c20de5e4c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c20de7b310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c20de7b5e0>],
#  'means': []}

# %%
a=(df1["Selling Price"]>upper_limit)|(df1["Selling Price"]<low_limit)

# %%
b=df1[a].index.values

# %%
df1.drop(b)
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# 1              15990
# 2              17990
# 3              17990
# 4              15990
# ...              ...
# 3109           25990
# 3110           28449
# 3111           31489
# 3112           22989
# 3113           22595
#
# [2756 rows x 8 columns]

# %%
df1
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# 1              15990
# 2              17990
# 3              17990
# 4              15990
# ...              ...
# 3109           25990
# 3110           28449
# 3111           31489
# 3112           22989
# 3113           22595
#
# [3114 rows x 8 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           3114 non-null   object
#  1   Model           3114 non-null   object
#  2   Color           3114 non-null   object
#  3   Memory          3071 non-null   object
#  4   Storage         3075 non-null   object
#  5   Rating          2970 non-null   float64
#  6   Selling Price   3114 non-null   int64
#  7   Original Price  3114 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 194.8+ KB

# %%
def IQR_values(df1,Column_name):
    q1=df1[Column_name].quantile(0.25)
    q2=df1[Column_name].quantile(0.50)
    q3=df1[Column_name].quantile(0.75)
    IQR=q3-q1
    low_limit=q1-1.5*IQR
    upper_limit=q3+1.5*IQR
    return low_limit,upper_limit

# %%
l=['Selling Price','Original Price']
j={}
for i in l:
   low_limit,upper_limit= IQR_values(df1,i)
   j[i]=[low_limit,upper_limit]

# %%
j
# Out:
# {'Selling Price': [-18523.5, 57512.5],
#  'Original Price': [-22174.375, 63704.625]}

# %%
for i in l:
    a=(df1[i]>j[i][1])|(df1[i]<j[i][0])
    
b=df1[a].index.values

# %%
b
# Out:
# array([ 256,  258,  259,  260,  261,  262,  263,  264,  265,  266,  267,
#         269,  270,  272,  273,  274,  276,  305,  318,  335,  409,  415,
#         425,  443,  466,  477, 1124, 1126, 1127, 1132, 1134, 1135, 1136,
#        1138, 1139, 1141, 1142, 1145, 1148, 1154, 1157, 1159, 1160, 1161,
#        1164, 1165, 1168, 1169, 1170, 1173, 1174, 1176, 1177, 1179, 1180,
#        1181, 1182, 1183, 1184, 1186, 1187, 1188, 1189, 1191, 1192, 1193,
#        1195, 1196, 1197, 1198, 1200, 1201, 1203, 1204, 1205, 1206, 1207,
#        1208, 1211, 1212, 1213, 1214, 1215, 1218, 1219, 1220, 1221, 1222,
#        1223, 1224, 1225, 1227, 1229, 1230, 1231, 1232, 1233, 1234, 1235,
#        1236, 1237, 1238, 1239, 1240, 1241, 1242, 1245, 1246, 1248, 1251,
#        1252, 1254, 1255, 1256, 1257, 1259, 1260, 1261, 1265, 1266, 1267,
#        1270, 1273, 1276, 1279, 1283, 1285, 1288, 1290, 1294, 1297, 1298,
#        1299, 1300, 1301, 1302, 1304, 1305, 1308, 1309, 1312, 1313, 1314,
#        1315, 1316, 1317, 1318, 1319, 1321, 1322, 1323, 1324, 1325, 1328,
#        1331, 1332, 1333, 1334, 1336, 1337, 1338, 1341, 1342, 1344, 1347,
#        1348, 1350, 1351, 1352, 1353, 1355, 1356, 1357, 1361, 1362, 1363,
#        1366, 1369, 1372, 1375, 1378, 1381, 1384, 1385, 1386, 1389, 1392,
#        1393, 1397, 1398, 1401, 1402, 1403, 1404, 1405, 1406, 1408, 1410,
#        1412, 1413, 1414, 1416, 1419, 1420, 1423, 1428, 1429, 1430, 1431,
#        1434, 1436, 1439, 1443, 1445, 1447, 1448, 1449, 1450, 1452, 1455,
#        1456, 1457, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1468,
#        1469, 1470, 1473, 1474, 1477, 1479, 1482, 1520, 1530, 1533, 1566,
#        1577, 1596, 1607, 1616, 1629, 1643, 1649, 1654, 1655, 1657, 1685,
#        1688, 1690, 1704, 1713, 1723, 1779, 1784, 1786, 1796, 1815, 1844,
#        1845, 1846, 1855, 1856, 1858, 1863, 1870, 1883, 1888, 1891, 1898,
#        1899, 1905, 1913, 1924, 1943, 1949, 1951, 1958, 1963, 1971, 1975,
#        1981, 1988, 1989, 1994, 1995, 1997, 1998, 2015, 2019, 2020, 2023,
#        2030, 2034, 2037, 2038, 2046, 2058, 2060, 2069, 2085, 2086, 2097,
#        2135, 2151, 2316, 2318, 2345, 2346, 2426, 2762, 2763, 2764, 2784,
#        3033, 3034, 3035, 3036, 3037, 3038, 3039, 3040, 3041, 3042, 3043,
#        3044, 3045, 3046, 3047, 3048, 3049, 3050, 3051, 3052, 3053, 3054,
#        3055, 3056, 3057, 3058], dtype=int64)
